# %%
import requests
from bs4 import BeautifulSoup
import json
from time import sleep
import random
from urllib import parse

# %%
url = 'https://sparktoro.com/score/cyberbrokers_'

# %%
res = requests.get(url)

# %%
res.text
# Out:
# '\n<!doctype html>\n<html lang="en">\n<head>\n<meta charset="utf-8" />\n<link rel="dns-prefetch" href="//pbs.twimg.com">\n<link rel="preconnect" href="https://fast.wistia.com">\n<link rel="preload" href="//sparktoro.com/css/sparktoro.416444caaec3f6baff77a48d498e904f.css" as="style">\n<link rel="preload" href="https://fonts.googleapis.com/css?family=Kumar+One|Kumar+One+Outline|Montserrat:300,300i,400,400i,500,500i,600,600i,700,700i|Open+Sans+Condensed:300,700|Open+Sans:300,300i,400,400i,600,600i,700,700i|Gloria+Hallelujah&display=swap" as="style" crossorigin>\n<link rel="preload" href="//sparktoro.com/js/sparktoro.e96f72fd1fa08f53853560802331b8ca.js" as="script">\n<link rel="canonical" href="https://sparktoro.com/tools/sparkscore" />\n<title>SparkScore from SparkToro</title>\n<meta name="description" content="SparkScore doesn\'t hide anything about how we calculate our numbers -- you can see exactly how the scoring is weighted, what numbers go into it, and how to influence your own sc
# ...
